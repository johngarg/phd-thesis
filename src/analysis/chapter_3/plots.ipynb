# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import constraints

# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

SMALL_SIZE = 20
MEDIUM_SIZE = 25
BIGGER_SIZE = 25

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.tight_layout()

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"]}
)

sns.set_palette("muted")

# %%
scan1_cll = pd.read_csv("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/data/scan1_cll.csv")
scan1_cllclr = pd.read_csv("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/data/scan1_cllclr.csv")
scan2 = pd.read_csv("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/data/scan2.csv")

# %%
scan1_cll_filtered = scan1_cll[
    (scan1_cll.rknunu < 2.7) &
    (scan1_cll.cbs < 1.11 + 2*0.09) &
    (scan1_cll.cbs > 1.11 - 2*0.09) &
    (scan1_cll.Dsmunu < (5.49 + 2*0.16)*1e-3) &
    (scan1_cll.Dsmunu > (5.49 - 2*0.16)*1e-3) &
    (scan1_cll.Bmunu > 2.9e-7) &
    (scan1_cll.Bmunu < 10.7e-7)
]

# %%
scan1_cllclr_filtered = scan1_cllclr[
    (scan1_cllclr.rknunu < 2.7) &
    (scan1_cllclr.cbs < 1.11 + 2*0.09) &
    (scan1_cllclr.cbs > 1.11 - 2*0.09) &
    (scan1_cllclr.Dsmunu < (5.49 + 2*0.16)*1e-3) &
    (scan1_cllclr.Dsmunu > (5.49 - 2*0.16)*1e-3) &
    (scan1_cllclr.Bmunu > 2.9e-7) &
    (scan1_cllclr.Bmunu < 10.7e-7)
]

# %%
scan2_filtered = scan2[
    (scan2.rknunu < 2.7) &
    (scan2.cbs < 1.11 + 2*0.09) &
    (scan2.cbs > 1.11 - 2*0.09) &
    (scan2.Dsmunu < (5.49 + 2*0.16)*1e-3) &
    (scan2.Dsmunu > (5.49 - 2*0.16)*1e-3) &
    (scan2.Bmunu > 2.9e-7) &
    (scan2.Bmunu < 10.7e-7)
]

# %%
scan2_filtered_cll_3sigma = scan2_filtered[(scan2_filtered.cll > -1.06 - 3*0.16) & (scan2_filtered.cll < -1.06 + 3*0.16)]

# %%
-1.06 - 2*0.16
# Out:
# -1.3800000000000001

# %%
scan2_filtered_cll_2sigma
# Out:
#        Unnamed: 0            m       x22       x23       x32       x33  \
# 5234         5234  3707.681998  0.170163 -3.283478 -0.170798  0.295381
# 7392         7392  3728.880946  0.150585 -3.533411  0.023392  0.186578
# 8118         8118  3528.328629  0.182682 -3.149495 -0.076848  0.064602
# 15149       15149  3693.643355 -0.141550  3.450623 -0.091933  0.457166
# 23137       23137  3858.953849 -0.167880  3.543791  0.037994  0.792231
# 32585       32585  4073.864781  0.191138 -3.495110  0.030188 -0.075645
# 33638       33638  4006.045903  0.183045 -3.500496  0.203879  0.016300
#
#             y23       y32        rd    rdstar       cll           clr  \
# 5234  -0.028599  0.407936  0.297538  0.249799 -0.781540 -6.298071e-05
# 7392  -0.022032  3.017233  0.394543  0.265726 -0.758395 -3.170381e-05
# 8118  -0.004205  2.056555  0.338747  0.257622 -0.751894 -1.428066e-06
# 15149 -0.008480  2.536491  0.378614  0.263454 -0.741485 -4.813386e-06
# ...

# %%
scan2_filtered_cll
# Out:
#        Unnamed: 0            m       x22       x23       x32       x33  \
# 5               5  4264.415311 -0.195116  2.768631 -0.123327  0.822291
# 11             11  4123.188274  0.194401 -2.877867  0.113468 -0.101751
# 92             92  4464.004569  0.161307 -3.053694 -0.283757  0.413391
# 222           222  4218.293957 -0.072277  3.062222  0.309632 -1.017674
# 244           244  3947.819766 -0.163106  3.083063 -0.233273 -0.068279
# ...           ...          ...       ...       ...       ...       ...
# 36670       36670  3243.916322  0.225260 -2.361061 -0.070332  0.082420
# 36695       36695  4538.368500 -0.176544  3.045359  0.254797 -0.252853
# 36699       36699  4169.104688 -0.174377  3.024301  0.054570  0.363044
# 36769       36769  4254.448463 -0.137083  3.306884 -0.111425  0.376373
# 36821       36821  4564.600586  0.160572 -3.301396  0.029101  0.642319
#
#             y23       y32        rd    rdstar       cll           clr  \
# ...

# %%
scan2_filtered_cll_3sigma.to_csv("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/data/mathematicaFitleredScanII_3sigma_cll.csv")

# %% [markdown]
# # Bec test plots

# %%
scan1_cll_filtered = scan1_cll_filtered.rename(columns={"m": r"$m_{S_1}$ [GeV]"})

# %%
f, ax = plt.subplots(figsize=(8, 6))

ax = sns.scatterplot(data=scan1_cll_filtered, x="cll", y="rdmue", hue=r"$m_{S_1}$ [GeV]")
ax.legend(loc="lower right")
ax.set(xlabel='$C_{LL}^{S_{1}}$', ylabel=r'$R_D^{\mu/e}$', xlim=(-1,0.5), ylim=(0.9,1.05))

ax.axvspan(-1.38, -0.74, alpha=0.2, color='gray')
ax.axvspan(-1.22, -0.9, alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_becTest.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(8, 6))

ax = sns.scatterplot(data=scan1_cll_filtered, x="cll", y="rdstaremu", hue="$m_{S_1}$ [GeV]")
ax.get_legend().remove()
ax.set(xlabel='$C_{LL}^{S_{1}}$', ylabel=r'$R_{D^*}^{e/\mu}$', xlim=(-1,0.5), ylim=(0.9,1.05))

ax.axvspan(-1.38, -0.74, alpha=0.2, color='gray')
ax.axvspan(-1.22, -0.9, alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_becTestStar.png",
           format='png', dpi=800)

# %% [markdown]
# # Other Scan 1 plots

# %%
f, ax = plt.subplots(figsize=(6,5))

ax = sns.scatterplot(data=scan1_cll_filtered, y="cll", x=r"$m_{S_1}$ [GeV]")
ax.set(ylabel='$C_{LL}^{S_{1}}$', xlabel=r'$\hat{m}_{S_1}$', ylim=(-1,0), xlim=(0,5000))

ax.axhspan(-1.38, -0.74, alpha=0.2, color='gray')
ax.axhspan(-1.22, -0.9, alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_cllm.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(6,5))

ax = sns.scatterplot(data=scan1_cll_filtered, x="x33x23", y="cll")
ax.set(xlabel='$x_{33}/x_{23}$', ylabel=r'$C_{LL}^{S_1}$', ylim=(-1,0), xlim=(-2,2))

ax.axhspan(-1.38, -0.74, alpha=0.2, color='gray')
ax.axhspan(-1.22, -0.9, alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_x33x23rat.png",
           format='png', dpi=800)

# %% [markdown]
# ## $b \to s$ coupling plots

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan1_cll_filtered, x="x22", y="cll")
ax.set(xlabel='$x_{22}$', ylabel=r'$C_{LL}^{S_1}$', ylim=(-1,0), xlim=(-3.5,3.5))

ax.axhspan(-1.38, -0.74, alpha=0.2, color='gray')
ax.axhspan(-1.22, -0.9, alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_cllx22.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan1_cll_filtered, x="x23", y="cll")
ax.set(xlabel='$x_{23}$', ylabel=r'$C_{LL}^{S_1}$', ylim=(-1,0), xlim=(-3.5,3.5))

ax.axhspan(-1.38, -0.74, alpha=0.2, color='gray')
ax.axhspan(-1.22, -0.9, alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_cllx23.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan1_cll_filtered, x="x32", y="cll")
ax.set(xlabel='$x_{32}$', ylabel=r'$C_{LL}^{S_1}$', ylim=(-1,0), xlim=(-3.5,3.5))

ax.axhspan(-1.38, -0.74, alpha=0.2, color='gray')
ax.axhspan(-1.22, -0.9, alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_cllx32.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan1_cll_filtered, x="x33", y="cll")
ax.set(xlabel='$x_{33}$', ylabel=r'$C_{LL}^{S_1}$', ylim=(-1,0), xlim=(-3.5,3.5))

ax.axhspan(-1.38, -0.74, alpha=0.2, color='gray')
ax.axhspan(-1.22, -0.9, alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_cllx33.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan1_cllclr_filtered, x="y22", y="cll")
ax.set(xlabel='$y_{22}$', ylabel=r'$C_{LL}^{S_1}$', ylim=(-1,0), xlim=(-3.5,3.5))

ax.axhspan(-1.38, -0.74, alpha=0.2, color='gray')
ax.axhspan(-1.22, -0.9, alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_clly22.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan1_cllclr_filtered, x="y23", y="cll")
#sns.scatterplot(data=scan1_cll_filtered, x="y23", y="cll", color="blue")
ax.set(xlabel='$y_{23}$', ylabel=r'$C_{LL}^{S_1}$', ylim=(-1,0), xlim=(-3.5,3.5))

ax.axhspan(-1.38, -0.74, alpha=0.2, color='gray')
ax.axhspan(-1.22, -0.9, alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_clly23.png",
           format='png', dpi=800)

# %% [markdown]
# ## $b \to c$ coupling plots

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan2_filtered, x="x22", y="rdstar_flav")
ax.set(xlabel='$x_{22}$', ylabel=r'$R_{D^*}$', ylim=(0.25,0.35), xlim=(-3.5,3.5))

ax.axhspan(0.295 - 2*np.sqrt(0.011**2 + 0.008**2), 0.295 + 2*np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')
ax.axhspan(0.295 - np.sqrt(0.011**2 + 0.008**2), 0.295 + np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_obsx22.png",
           format='png', dpi=800)

# %%
scan2_filtered_x23 = scan2_filtered[(scan2_filtered['cll'] > -0.01) & (scan2_filtered['cll'] < 0.01)]

# %%
scan2_filtered_x23
# Out:
#        Unnamed: 0            m       x22       x23       x32       x33  \
# 6               6  4589.223983  0.040877  0.270983 -1.253831 -0.249367
# 10             10  2906.481802  0.072274 -0.084379  0.261121  0.772381
# 12             12  4537.824524 -0.088253  0.239876 -0.802180 -0.160925
# 13             13  4845.810469  0.069441  0.851442 -0.111159  0.242073
# 14             14  4836.608850  0.069213 -0.148912  0.804848  0.417568
# ...           ...          ...       ...       ...       ...       ...
# 36857       36857  3409.760604  0.216844 -0.766135 -0.689485 -0.151618
# 36858       36858  3754.161194  0.040147  0.835712 -0.132467  0.559556
# 36860       36860  4982.630331  0.099615  0.440111  2.456838  0.017407
# 36861       36861  4515.562535  0.193118  0.151415  0.161529 -3.372014
# 36865       36865  1000.000000  0.000000  0.000000  0.000000  1.300000
#
#             y23       y32        rd    rdstar       cll           clr  \
# ...

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan2_filtered, x="x23", y="rdstar_flav")
sns.scatterplot(data=scan2_filtered_x23, x="x23", y="rdstar_flav")
ax.set(xlabel='$x_{23}$', ylabel=r'$R_{D^*}$', ylim=(0.25,0.35), xlim=(-3.5,3.5))

ax.axhspan(0.295 - 2*np.sqrt(0.011**2 + 0.008**2), 0.295 + 2*np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')
ax.axhspan(0.295 - np.sqrt(0.011**2 + 0.008**2), 0.295 + np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_obsx23.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan2_filtered, x="x32", y="rdstar_flav")
ax.set(xlabel='$x_{32}$', ylabel=r'$R_{D^*}$', ylim=(0.25,0.35), xlim=(-3.5,3.5))

ax.axhspan(0.295 - 2*np.sqrt(0.011**2 + 0.008**2), 0.295 + 2*np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')
ax.axhspan(0.295 - np.sqrt(0.011**2 + 0.008**2), 0.295 + np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_obsx32.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan2_filtered, x="x33", y="rdstar_flav")
ax.set(xlabel='$x_{33}$', ylabel=r'$R_{D^*}$', ylim=(0.25,0.35), xlim=(-3.5,3.5))

ax.axhspan(0.295 - 2*np.sqrt(0.011**2 + 0.008**2), 0.295 + 2*np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')
ax.axhspan(0.295 - np.sqrt(0.011**2 + 0.008**2), 0.295 + np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_obsx33.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan2_filtered, x="y23", y="rdstar_flav")
ax.set(xlabel='$y_{23}$', ylabel=r'$R_{D^*}$', ylim=(0.25,0.35), xlim=(-0.05,0.05))

ax.axhspan(0.295 - 2*np.sqrt(0.011**2 + 0.008**2), 0.295 + 2*np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')
ax.axhspan(0.295 - np.sqrt(0.011**2 + 0.008**2), 0.295 + np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_obsy23.png",
           format='png', dpi=800)

# %%
f, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(data=scan2_filtered, x="y32", y="rdstar_flav")
ax.set(xlabel='$y_{32}$', ylabel=r'$R_{D^*}$', ylim=(0.25,0.35), xlim=(-3.5,3.5))

ax.axhspan(0.295 - 2*np.sqrt(0.011**2 + 0.008**2), 0.295 + 2*np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')
ax.axhspan(0.295 - np.sqrt(0.011**2 + 0.008**2), 0.295 + np.sqrt(0.011**2 + 0.008**2), alpha=0.2, color='gray')

plt.tight_layout()
plt.savefig("/Users/johngargalionis/Dropbox/PhD/Thesis/phd-thesis/src/img/chapter_3/new_obsy32.png",
           format='png', dpi=800)
